# %%
import requests

# %%
def create_headers(bearer_token):
    headers = {"Authorization": "Bearer {}".format(bearer_token)}
    return headers

def connect_to_endpoint(url, headers, next_token = None):    
    response = requests.request("GET", url, headers = headers)
    
    print("Endpoint Response Code: " + str(response.status_code))
    
    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    return response.json()

# %%
header = create_headers('AAAAAAAAAAAAAAAAAAAAAA%2BRTAEAAAAAKLM1VoUBpVp7VsDcjKkzVHpEMlM%3D1NrtYvI3CTJP7lSY7uVrfNBOdTCrtgAvxXtoautNnQJjLI4M45')
conversation_id = '1470928804470210560'
max_results = 30
params = 'in_reply_to_user_id,author_id,created_at,conversation_id'
getConversation_url = f'https://api.twitter.com/2/tweets/search/recent?query=conversation_id:{conversation_id}&tweet.fields={params}&max_results={max_results}'

# %%
connect_to_endpoint(getConversation_url, header)
# Out:
# Endpoint Response Code: 200
# {'data': [{'conversation_id': '1470928804470210560',
#    'id': '1474973816182956032',
#    'created_at': '2021-12-26T05:22:16.000Z',
#    'text': '@blurryblue2468 @JK_Leatherass @TekshowPlays @POTUS Nobody thinks Covid is well just because trump said it is. Or Biden.',
#    'in_reply_to_user_id': '1465857673702875137',
#    'author_id': '3298657684'},
#   {'conversation_id': '1470928804470210560',
#    'id': '1474956979185623041',
#    'created_at': '2021-12-26T04:15:21.000Z',
#    'text': '@Bidenwonthnkgod @POTUS In your obnoxious attempt to seem intelligent you completely missed the point of that GIF. https://t.co/02pi2QsHyW',
#    'in_reply_to_user_id': '1335088473951383552',
#    'author_id': '1061100141871017984'},
#   {'conversation_id': '1470928804470210560',
#    'id': '1474938941837127685',
#    'created_at': '2021-12-26T03:03:41.000Z',
#    'text': '@sawyermontoy @POTUS Do you know what a virus does when it’s not squashed? Mutation. When a virus replicates, and the end copy has differences (in DNA or RNA), those differences are mutations. Variant. When you accumulate enough mutations, you get a variant. Dumb ppl think it’s moving the goal post',
#    'in_reply_to_user_id': '1061100141871017984',
#    'author_id': '1335088473951383552'},
#   {'conversation_id': '1470928804470210560',
#    'id': '1474835823157604353',
#    'created_at': '2021-12-25T20:13:56.000Z',
#    'text': '@blurryblue2468 @0dvimes @JK_Leatherass @POTUS Oh please, that’s your next strawman Argument, Covid is only real cause a president said so? Pretty powerful that he convinced the rest of the entire world it was real too. Fact checked, right, clearly you lack the ability. You mean confirmation bias. \n\nJust sit down… 🤦\u200d♂️',
#    'in_reply_to_user_id': '1465857673702875137',
#    'author_id': '845608229723766785'},
#   {'conversation_id': '1470928804470210560',
#    'id': '1474822031350775808',
#    'created_at': '2021-12-25T19:19:07.000Z',
#    'text': "@POTUS @JoeBiden Hey, this is Rayhan i'm a digital marketer and SEO specialist. If you want to promote your YouTube video please click on this link. 👇\nhttps://t.co/nm4Vwj5ae8",
#    'in_reply_to_user_id': '1349149096909668363',
#    'author_id': '1472682117247090688'},
#   {'conversation_id': '1470928804470210560',
#    'id': '1474790441639989248',
#    'created_at': '2021-12-25T17:13:36.000Z',
#    'text': '@Bidenwonthnkgod @POTUS https://t.co/MekhCzE8de',
#    'in_reply_to_user_id': '1335088473951383552',
#    'author_id': '1061100141871017984'},
#   {'conversation_id': '1470928804470210560',
#    'id': '1474765688187273221',
#    'created_at': '2021-12-25T15:35:14.000Z',
#    'text': '@Diane79861618 @THEDarkKittee @POTUS I feel sorry for you if you think Fox entertainment channel is actually news. Any serious broadcaster has left that network. U think MSM is fake because a corrupt pres told you it was cuz they portrayed him for what he is. He’s going to jail but keep harping on hunters laptop 🤡',
#    'in_reply_to_user_id': '985332104522338304',
#    'author_id': '1335088473951383552'},
#   {'conversation_id': '1470928804470210560',
#    'id': '1474764333271896067',
#    'created_at': '2021-12-25T15:29:51.000Z',
#    'text': '@Katielou9156 @POTUS You’re a 🤡 . Millions of deaths from Covid and mainly the deaths this year is due to misinfo like your dumb statement killing off GOP voters. While GOP politicians are all vaxed. They love the uneducated.',
#    'in_reply_to_user_id': '1472262519511293952',
#    'author_id': '1335088473951383552'},
#   {'conversation_id': '1470928804470210560',
#    'id': '1474763894459703304',
#    'created_at': '2021-12-25T15:28:06.000Z',
#    'text': '@sawyermontoy @POTUS This post is about deaths. Not cases. Pay attention.',
#    'in_reply_to_user_id': '1061100141871017984',
#    'author_id': '1335088473951383552'},
#   {'conversation_id': '1470928804470210560',
#    'id': '1474763600405401603',
#    'created_at': '2021-12-25T15:26:56.000Z',
#    'text': '@NYIrishfan @POTUS Pay attention to what I posted shall we instead of deflecting? This is about deaths not cases.',
#    'in_reply_to_user_id': '1399042030517559298',
#    'author_id': '1335088473951383552'},
#   {'conversation_id': '1470928804470210560',
#    'id': '1474735359590375425',
#    'created_at': '2021-12-25T13:34:43.000Z',
#    'text': "@0dvimes @JK_Leatherass @TekshowPlays @POTUS It's factual evidence which I fact checked myself. You can do it too. Also, I don't think believing COVID because the president said it was real is very good research either so... good point, not even gonna lie, but it is a bit hypocritical.",
#    'in_reply_to_user_id': '3298657684',
#    'author_id': '1465857673702875137'},
#   {'conversation_id': '1470928804470210560',
#    'id': '1474623931772555267',
#    'created_at': '2021-12-25T06:11:57.000Z',
#    'text': '@POTUS You need to pray for the patients that health care workers will be infecting when you require them to go back to work in 5 to 7 days after a positive covid-19 test while you require the general public to isolate for 10 days.',
#    'in_reply_to_user_id': '1349149096909668363',
#    'author_id': '2504183177'},
#   {'conversation_id': '1470928804470210560',
#    'id': '1474610458934005765',
#    'created_at': '2021-12-25T05:18:25.000Z',
#    'text': '@POTUS @JoeBiden Say there is no god but God alone, without partner, to Him belongs the kingdom and to Him is praise, and He is over all things powerful, and I bear witness that Muhammad is the Messenger of God, for our true Islamic religion is the religion of chastity, dignity and purity. https://t.co/ckNJUICeue',
#    'in_reply_to_user_id': '1349149096909668363',
#    'author_id': '1449350675603890181'},
#   {'conversation_id': '1470928804470210560',
#    'id': '1474490976362110978',
#    'created_at': '2021-12-24T21:23:38.000Z',
#    'text': '@POTUS @JoeBiden https://t.co/D1UabLDh6x',
#    'in_reply_to_user_id': '1349149096909668363',
#    'author_id': '200170561'},
#   {'conversation_id': '1470928804470210560',
#    'id': '1474490950965555200',
#    'created_at': '2021-12-24T21:23:32.000Z',
#    'text': '@POTUS https://t.co/WERllpUgE8',
#    'in_reply_to_user_id': '1349149096909668363',
#    'author_id': '200170561'},
#   {'conversation_id': '1470928804470210560',
#    'id': '1474393860889616392',
#    'created_at': '2021-12-24T14:57:44.000Z',
#    'text': '@Robertmroz86 @David_Spiegel @KJTmpma @POTUS And everyone on the left said all the 400k deaths from COVID were trumps@fault.. so the 500k that have died since Biden are his fault? How come they don’t report that story anymore?',
#    'in_reply_to_user_id': '776605595621269504',
#    'author_id': '1445842571914211333'},
#   {'conversation_id': '1470928804470210560',
#    'id': '1474393435675271180',
#    'created_at': '2021-12-24T14:56:02.000Z',
#    'text': '@David_Spiegel @Robertmroz86 @KJTmpma @POTUS How did you get that from that tweet I swear u liberals are crazy as hell people like me are realist I like things the republicans do and I agree with some of the things democrats do so I’m in the middle. I would rather mean tweets over this shit show of a presidency',
#    'in_reply_to_user_id': '44681229',
#    'author_id': '1445842571914211333'},
#   {'conversation_id': '1470928804470210560',
#    'id': '1474392099516817411',
#    'created_at': '2021-12-24T14:50:44.000Z',
#    'text': '@Robertmroz86 @David_Spiegel @KJTmpma @POTUS No everyone said vote for Biden he will get the virus under control that’s the only reason he won the election the left wing media def kept@saying Biden has a plan to rid COVID',
#    'in_reply_to_user_id': '776605595621269504',
#    'author_id': '1445842571914211333'},
#   {'conversation_id': '1470928804470210560',
#    'id': '1474391864564461571',
#    'created_at': '2021-12-24T14:49:48.000Z',
#    'text': '@Robertmroz86 @David_Spiegel @KJTmpma @POTUS And no boys don’t get old but an old guying using that word like he’s hip or cool does. Just because your kid thinks ur cool doesn’t mean you are',
#    'in_reply_to_user_id': '776605595621269504',
#    'author_id': '1445842571914211333'},
#   {'conversation_id': '1470928804470210560',
#    'id': '1474391345657749512',
#    'created_at': '2021-12-24T14:47:44.000Z',
#    'text': '@Robertmroz86 @David_Spiegel @KJTmpma @POTUS According to all your past tweets he is!',
#    'in_reply_to_user_id': '776605595621269504',
#    'author_id': '1445842571914211333'},
#   {'conversation_id': '1470928804470210560',
#    'id': '1474389239974477830',
#    'created_at': '2021-12-24T14:39:22.000Z',
#    'text': '@MarkNic06063225 @David_Spiegel @KJTmpma @POTUS No one was saying that on the left.  It was all trump supporters saying that bc they believed it was fake.  So it would vanish after the election and it was used to scare people to do mail in voting.',
#    'in_reply_to_user_id': '1445842571914211333',
#    'author_id': '776605595621269504'},
#   {'conversation_id': '1470928804470210560',
#    'id': '1474388597738557447',
#    'created_at': '2021-12-24T14:36:49.000Z',
#    'text': "@MarkNic06063225 @David_Spiegel @KJTmpma @POTUS Lol.  Bots get old?\nBiden is an old turd.\nI am not a fan of his.\n So to say he's my savior is laughable.",
#    'in_reply_to_user_id': '1445842571914211333',
#    'author_id': '776605595621269504'},
#   {'conversation_id': '1470928804470210560',
#    'id': '1474386299738013696',
#    'created_at': '2021-12-24T14:27:41.000Z',
#    'text': '@David_Spiegel @Robertmroz86 @KJTmpma @POTUS The right wing media all have the vaccines you idiots they all say it’s your decision in your health not the governments.. also where have the vaccines gotten us ? I thought this was going to be over when Biden won that’s what the Biden lovers on Twitter all kept saying',
#    'in_reply_to_user_id': '44681229',
#    'author_id': '1445842571914211333'},
#   {'conversation_id': '1470928804470210560',
#    'id': '1474385940131069958',
#    'created_at': '2021-12-24T14:26:15.000Z',
#    'text': "@tonyggir @POTUS I would also like him to hone in on the black population because of the Tuskegee experiment; I would like him to let them know to stop thinking about that and GET VAXXED!!! I am part black, so I can say that. I got mine and I'm boosted btw.",
#    'in_reply_to_user_id': '114809319',
#    'author_id': '96572744'},
#   {'conversation_id': '1470928804470210560',
#    'id': '1474385878982266881',
#    'created_at': '2021-12-24T14:26:00.000Z',
#    'text': '@David_Spiegel @Robertmroz86 @KJTmpma @POTUS I literally watch both channels but u know everything I forgot! Just because you think Biden is your savior and you can’t try to see both sides doesn’t mean I don’t.  And btw you are both to old to be talking about BOTS that’s for the kids guys',
#    'in_reply_to_user_id': '44681229',
#    'author_id': '1445842571914211333'},
#   {'conversation_id': '1470928804470210560',
#    'id': '1474385237010440192',
#    'created_at': '2021-12-24T14:23:27.000Z',
#    'text': "@POTUS I have heard that a lot of the black population is refusing because of the Tuskegee experiment....PLEASE DO SOMETHING ABOUT THAT!!!!!! I CAN'T TAKE IT ANYMORE!!!!",
#    'in_reply_to_user_id': '1349149096909668363',
#    'author_id': '96572744'},
#   {'conversation_id': '1470928804470210560',
#    'id': '1474369943118430230',
#    'created_at': '2021-12-24T13:22:41.000Z',
#    'text': '@POTUS @JoeBiden https://t.co/gdeX7XeF0c',
#    'in_reply_to_user_id': '1349149096909668363',
#    'author_id': '1467903591163875340'},
#   {'conversation_id': '1470928804470210560',
#    'id': '1474261163156328454',
#    'created_at': '2021-12-24T06:10:26.000Z',
#    'text': '@POTUS @JoeBiden Yeah grt the vaccine so joe gets his cut And hey looser those numbers are fake https://t.co/aUlbdKn4m7',
#    'in_reply_to_user_id': '1349149096909668363',
#    'author_id': '1423336684343730186'},
#   {'conversation_id': '1470928804470210560',
#    'id': '1474205461868126208',
#    'created_at': '2021-12-24T02:29:06.000Z',
#    'text': '@GLI_ResearchLib @sassybibrarian @POTUS https://t.co/HDRT6WU1do',
#    'in_reply_to_user_id': '1434029581363650565',
#    'author_id': '1235197439012814850'},
#   {'conversation_id': '1470928804470210560',
#    'id': '1474188073273495570',
#    'created_at': '2021-12-24T01:20:00.000Z',
#    'text': '@Maxwellf39 @Katielou9156 @POTUS Okay little boy. It’s time to move on now. https://t.co/69b3Fbr2eW',
#    'in_reply_to_user_id': '778183048064016384',
#    'author_id': '1357764472258007041'}],
#  'meta': {'newest_id': '1474973816182956032',
#   'oldest_id': '1474188073273495570',
#   'result_count': 30,
#   'next_token': 'b26v89c19zqg8o3fpe170qln7tjvtxgmfv5ord3t8sakd'}}
