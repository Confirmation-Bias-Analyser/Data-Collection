# %%
from functions import *

# %%
with open('Authentication/database_uri.txt', 'r', encoding="utf8") as f:
    uri = f.read()

# %%
# The 3 tables:

# command = '''
#     CREATE TABLE twitter_data (
#     tweet_id VARCHAR NOT NULL,
#     timestamp VARCHAR NOT NULL,
#     tweet VARCHAR
# )
# '''

# command = '''
#     CREATE TABLE reddit_data (
#     post_id VARCHAR NOT NULL,
#     timestamp VARCHAR NOT NULL,
#     post VARCHAR
# )
# '''

# command = '''
#     CREATE TABLE tweets_for_analysis (
#     id VARCHAR NOT NULL,
#     timestamp VARCHAR NOT NULL,
#     reply_to VARCHAR NOT NULL,
#     comment VARCHAR NOT NULL,
#     social_media VARCHAR,
#     head_id VARCHAR NOT NULL,
#     conversation_id VARCHAR NOT NULL
# )
# '''

# command = '''
#     CREATE TABLE reddit_posts_for_analysis (
#     id VARCHAR NOT NULL,
#     username VARCHAR NOT NULL,
#     timestamp VARCHAR NOT NULL,
#     reply_to VARCHAR NOT NULL,
#     comment VARCHAR NOT NULL,
#     social_media VARCHAR,
#     head_id VARCHAR NOT NULL
# )
# '''

# command = '''ALTER TABLE tweets_for_analysis RENAME TO comments_for_analysis'''

# command = '''
#     DELETE FROM comments_for_analysis WHERE conversation_id = 'rmqevj'
# '''

# setUpDB(command, uri)

# %%
query = '''
    select * from comments_for_analysis
'''

data = getData(query, uri)
print('Length of dataframe:', len(data))
print(data['conversation_id'].unique())

data.head()
# Out:
# Length of dataframe: 626
# ['1505784753043124225' '1505413972568072195' '1505410767801106434'
#  '1505085602051502085' '1504381389818368001' '1504393380503044098'
#  '1506133764597985282' '1504786465091321859' '1513446924401410050'
#  '1507903248820150276' '1507922082683793408' '1507745670618251264'
#  '1507558981622853632' '1506830905687511040' '1513829591038627840'
#  'rmqevj']
#       id                 timestamp    reply_to  \
# 0  10000  2022-03-22T10:03:19.000Z       10003
# 1  10006  2022-03-22T02:05:17.000Z       10041
# 2  10012  2022-03-21T19:09:50.000Z  1619325942
# 3  10017  2022-03-21T14:55:31.000Z       10018
# 4  10022  2022-03-21T13:28:25.000Z  1619325942
#
#                                              comment social_media     head_id  \
# 0  @oterenceo @MothershipSG Definitely, there is ...      Twitter  1619325942
# 1  @treasured1964 @MothershipSG They dun get to c...      Twitter  1619325942
# 2  @MothershipSG Absolutely heartbreaking. My con...      Twitter  1619325942
# 3  @teamus712 @MothershipSG Say you’ve never felt...      Twitter  1619325942
# 4  @MothershipSG experienced twice with KKH hospi...      Twitter  1619325942
#
#        conversation_id
# 0  1505784753043124225
# 1  1505784753043124225
# 2  1505784753043124225
# 3  1505784753043124225
# 4  1505784753043124225

# %%
data[data['conversation_id'] == 'rmqevj']
# Out:
#           id             timestamp             reply_to  comment  \
# 576  hpp7l4j  OutlandishnessCalm42  2021-12-24 00:45:22  hpo6fwl
# 577  hpr2kav           MapleViolet  2021-12-24 08:55:24   rmqevj
# 578  hra9zzo         HaddockFillet  2022-01-05 08:14:35  hpr2kav
# 579  hpob7bq               kuang89  2021-12-23 20:17:48   rmqevj
# 580  hpprwf1             [deleted]  2021-12-24 03:06:33  hpob7bq
# 581  hprs02i               kuang89  2021-12-24 12:23:36  hpprwf1
# 582  hpr7oz0                yourm2  2021-12-24 09:37:07  hpob7bq
# 576  Transparency of government and integrity in Pa...  Reddit          rmqevj
# 577  All I know is - anyone trying to pull a fast o...  Reddit          rmqevj
# 578  Why does she think it is OK to lie about such ...  Reddit          rmqevj
# 579  A lie was told in parliament that affects the ...  Reddit          rmqevj
# 580  I would like to add "Public trust in a critica...  Reddit          rmqevj
# 581  Ya missed out on that, police public image als...  Reddit          rmqevj
# 582                                  need to jail her.  Reddit          rmqevj
# 583  This is the annoying part. Some of you make it...  Reddit          rmqevj
# 584  Here’s some perspective: \n\n1) The public nat...  Reddit          rmqevj
# 585  Well said. It’s only a problem if your party i...  Reddit          rmqevj
# 586  &gt;Transparency and finding out the truth is ...  Reddit          rmqevj
# 587  'Im so done with RK Saga because it sucks to b...  Reddit          rmqevj
# 588  how about feeling woke criticizing both PAP an...  Reddit          rmqevj
# 589  That's not being woke. That's just being ratio...  Reddit          rmqevj
# 590  Nah, "wokeness" is only reserved for Oppositio...  Reddit          rmqevj
# 591  Well the thing is a lot of these 'Woke' people...  Reddit          rmqevj
# 592  lmao I remember being downvoted for comparing ...  Reddit          rmqevj
# 593  people write these sorts of things thinking to...  Reddit          rmqevj
# 594  RK's actions hasn't set WP back that much, WP'...  Reddit          rmqevj
# 595     sure. I am not taking a position on the cause.  Reddit          rmqevj
# 596  Transparency. That thing that's only applicabl...  Reddit          rmqevj
# 597  MMTF might be moving goalposts but WP fans wil...  Reddit          rmqevj
# 598  If I made the same comment, I'd get like a 100...  Reddit          rmqevj
# 599  &gt; good to know the echo chamber can be brok...  Reddit          rmqevj
# 600  Yup I think there’s a lot of us around, but as...  Reddit          rmqevj
# 601  &gt;Transparency and finding out the truth is ...  Reddit          rmqevj
# 602  There will be many asking for more popcorn, bu...  Reddit          rmqevj
# 603  Please don't pretend that the opposition won't...  Reddit          rmqevj
# 604                              OWNSELF CHECK OWNSELF  Reddit          rmqevj
# 605  Tbh touch my heart, whether is wp pap or whate...  Reddit          rmqevj
# 606  There is merit in investigating the circumstan...  Reddit          rmqevj
# 607  Advantage of incumbency and majority. Same adv...  Reddit          rmqevj
# 608  I would disagree. They have employed legal cro...  Reddit          rmqevj
# 609  Except that in a ordinary court, cross-examina...  Reddit          rmqevj
# 610  exactly, fully agreed on this. furthermore the...  Reddit          rmqevj
# 611  Well that's exactly what you need to do to fin...  Reddit          rmqevj
# 612  Are you saying that the COP is the ideal mediu...  Reddit          rmqevj
# 613  I agree with you that it is reasonable. Althou...  Reddit          rmqevj
# 614  what messages does raeesah have, besides the o...  Reddit          rmqevj
# 615  Firstly, why would she (RK) lie to the closest...  Reddit          rmqevj
# 616  I feel that WP are being sour grapes about thi...  Reddit          rmqevj
# 617  I believe PAP has also failed to investigate o...  Reddit          rmqevj
# 618  Well said. Maybe we should revisit the TraceTo...  Reddit          rmqevj
# 619  &gt;It's such a blatant lie. \n\nWe don't have...  Reddit          rmqevj
# 620  Even if Vivian genuinely thought he was tellin...  Reddit          rmqevj
# 621  &gt;the fact that the other PAP members who kn...  Reddit          rmqevj
# 622  It was a matter of a legal technicality, a law...  Reddit          rmqevj
# 623  &gt; We don't have a thought police that can 1...  Reddit          rmqevj
# 624  &gt; Any competent person would have explored ...  Reddit          rmqevj
# 625  Why do you always copypasta this TraceTogether...  Reddit          rmqevj
